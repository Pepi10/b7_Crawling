# %% [raw]
# 1. 목표 설정
#   최근 트랜드를 읽어
#   좋은 컨텐츠가 포함된 aws 강의를 개설할 것이다
#
#   1-1 트랜드
#   [ 강의 가격, 수요, 공급, 강의 목차, 강의 방식, 온오프 유무]
#
#   AWS 강의 시장의 성장률을 분석하여 예상 수익을 예측. 이를 통해 시장의 향후 동향을 파악하고   비즈니스 전략을 수립
#
# 2. 크롤링 대상 사이트 선정
#
#   2-1 취업시장 /
#   잡코리아, 사람인, wanted
#   [ 회사들의 취업자 요구 능력을 파악 ] [ aws 가능자 취업 수요 ]
#
#   2-2 강의 /
#   AWS 공식 홈페이지
#   인프런, 부트텐트, Udemy, 코딩애플, 구름EDU, 유데미, 유튜브
#   [ 강의목차, 가격, 공급량, 강의방식, 강의를 수강한 고객의 리뷰 파악]
#
# 3. 크롤링 기술 선택
#   [ beautifulsoup, selenium ]
#
#
# 4. 데이터 수집 및 저장
#
#
# 5. 데이터 분석 및 시각화
#   수집한 데이터를 분석, 시각화
#   ex) 강의 제공자별 평가, 강의 가격대별 분포
#
#
# 6. 결과 해석 및 활용
#   분석 해석 및 인사이트 도출
#
#
# 김재경_수정
# 이주복_수정

# %% [raw]
# aws를 배워야 하는 이유
#
# * 클라우드 컴퓨팅의 중요성:
# 클라우드 컴퓨팅은 기업과 조직이 IT 인프라를 효율적으로 관리하고 스케일링하는 데 필수적입니다.
# AWS는 클라우드 컴퓨팅 분야에서 글로벌 리더이며, 다양한 클라우드 서비스를 제공하고 있습니다.
#
# * 비용 효율성:
# AWS는 비용 효율적으로 IT 리소스를 관리할 수 있는 도구와 서비스를 제공합니다.
# 클라우드 서비스를 사용하면 하드웨어 구매 및 유지 관리 비용을 줄일 수 있으며,
# 필요에 따라 리소스를 조절할 수 있습니다.
#
# * 신속한 프로비저닝:
# AWS를 사용하면 신속하게 가상 서버, 데이터베이스, 스토리지 등을 프로비저닝하고
# 개발 환경을 설정할 수 있습니다. 이로써 개발 및 배포 프로세스를 가속화할 수 있습니다.
#
# * 확장성:
# AWS는 서비스를 확장하기 쉽게 만들어주는 많은 옵션을 제공합니다.
# 애플리케이션의 요구 사항에 따라 서버 및 리소스를 쉽게 확장하거나 축소할 수 있습니다.
#
# * 보안 및 컴플라이언스:
# AWS는 강력한 보안 기능과 컴플라이언스를 제공하여 데이터 및 애플리케이션을 안전하게 보호할 수 있습니다.
# AWS는 다양한 보안 서비스를 제공하며, GDPR, HIPAA와 같은 규정 및 규정 준수에 대한 도움말도 제공합니다.
#
# * 자동화 및 관리:
# AWS는 자동화 및 관리를 위한 도구와 서비스를 제공하여
# IT 운영 및 관리 작업을 자동화하고 효율화할 수 있습니다.
# 이로써 운영 오버헤드를 줄이고 안정성을 높일 수 있습니다.
#
# * 경쟁 우위 유지:
# AWS 스킬은 현대의 기술 업계에서 경쟁 우위를 확보하는 데 도움이 됩니다.
# 많은 기업이 AWS를 사용하고 있으므로 AWS 스킬은 채용 시장에서 매우 가치 있는 자산입니다.
#
# * 새로운 기술 및 서비스 학습:
# AWS는 지속적으로 새로운 서비스와 기술을 출시하므로 학습 및 성장의 기회를 제공합니다.
# 클라우드 컴퓨팅 및 관련 기술의 발전을 따라가기 위해 AWS 스킬이 필요합니다.

# %% [markdown]
# 강의 컬럼
#
# 운영기업 / 비용 / 사전지식(필요기술) / 요일시간 / 장비? / 지원자격  / 과정 / 수업장소 / 선발절차 /
#
# 지원금? / 모집상태 / 기간 / 수업방식 / 프로젝트 / 채용연계
